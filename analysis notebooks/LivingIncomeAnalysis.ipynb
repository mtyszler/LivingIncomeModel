# %% [markdown]
# # Living Income Analysis

# %% [markdown]
# ## Summary:

# %% [markdown]
# In this notebook analyze whether cocoa farmers in Ghana and Côte d'Ivoire reach a Living Income.
#
# I use as starting point the [dataset](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/82TWZJ) from the [Demystifying the Cocoa study](https://www.kit.nl/project/demystifying-cocoa-sector/), and build on the work published [here](https://c69aa8ac-6965-42b2-abb7-0f0b86c23d2e.filesusr.com/ugd/0c5ab3_fc3386a550b94a898c7757ee13ab59e6.pdf) and [here](https://c69aa8ac-6965-42b2-abb7-0f0b86c23d2e.filesusr.com/ugd/0c5ab3_93560a9b816d40c3a28daaa686e972a5.pdf)

# %% [markdown]
# In this notebook, specifically I will:
# * Load the data
# * Do an initial variable and feature selection from the original dataset
# * Create Analytical groups
# * Calculate household income, performing data imputation where needed
# * Create a variable with the Living Income value per household and an indicator variable on whether this is achieved
# * Analyze the key indicators
# * Clean the remainder of the dataset
# * Prepare the dataset for Machine Learning

# %% [markdown]
# # 0. Initial (Data) processing

# %% [markdown]
# ## 0.1 Preamble

# %% [markdown]
# First I load all libraries to be used:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# magic word for producing visualizations in notebook
# %matplotlib inline

import seaborn as sns#; sns.set(style="ticks", color_codes=True)
import json

# %% [markdown]
# ## 0.2 Data Import and initial feature  & observation selection

# %% [markdown]
# Load the data from stata, which has already been partially cleaned/treated, since it comes from a curated public data repository.
#
# The dataset is extracted from https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/82TWZJ
# in stata 14 binary format.
#
# It is part of the research project described more broadly at https://www.kit.nl/project/demystifying-cocoa-sector/

# %%
data = pd.read_stata("../data/Cocoa_Livelihoods_export_Dataverse.dta") # data
data_properties = pd.read_stata("../data/Cocoa_Livelihoods_export_Dataverse.dta", iterator = True) #meta data

# %% [markdown]
# I initialliy inspect the data:

# %%
print("Shape of data set:", data.shape)
# Out:
# Shape of data set: (3045, 1252)

# %% [markdown]
# First few rows

# %%
data.head(10)
# Out:
#         today country region_comparable up_region   region         sub_region  \
# 0   26-dec-16   Ghana           Ashanti     Ghana  Ashanti      Atwima Mponua
# 1   27-dec-16   Ghana           Ashanti     Ghana  Ashanti   Atwima Nwabiagya
# 2   04-dec-16   Ghana           Ashanti     Ghana  Ashanti        Adansi West
# 3   03-dec-16   Ghana           Ashanti     Ghana  Ashanti  Bosomtwi Kwanwoma
# 4   03-dec-16   Ghana           Ashanti     Ghana  Ashanti  Bosomtwi Kwanwoma
# 5  2-dec-2016   Ghana           Ashanti     Ghana  Ashanti        Adansi East
# 6   03-dec-16   Ghana           Ashanti     Ghana  Ashanti  Bosomtwi Kwanwoma
# 7   27-dec-16   Ghana           Ashanti     Ghana  Ashanti   Atwima Nwabiagya
# 8   29-dec-16   Ghana           Ashanti     Ghana  Ashanti     Afigya Sekyere
# 9   04-dec-16   Ghana           Ashanti     Ghana  Ashanti        Adansi West
#
#      village  latitude  longitude consent_yn  ...  foodsec_bin_3  \
# ...

# %% [markdown]
# See some descriptive statistics

# %%
data.describe()
# Out:
#           latitude    longitude  hhmem_number  male_adults_over_65  \
# count  2210.000000  2210.000000   3004.000000          3004.000000
# mean      6.429661    -4.112733      6.264314             0.142144
# std       0.697673     1.894443      3.200178             0.374114
# min       4.840000    -8.200000      1.000000             0.000000
# 25%       5.940000    -5.447500      4.000000             0.000000
# 50%       6.470000    -3.870000      6.000000             0.000000
# 75%       6.930000    -2.500000      8.000000             0.000000
# max       7.840000    -0.470000     21.000000             5.000000
#
#        female_adults_over_65  male_adults_15_65  female_adults_15_65  \
# count            3004.000000        3004.000000          3004.000000
# mean                0.147803           1.689747             1.705726
# std                 0.402447           1.247421             1.181760
# min                 0.000000           0.000000             0.000000
# ...

# %% [markdown]
# Take a look at the full list of variables and variable labels:

# %%
print(json.dumps(data_properties.variable_labels(), indent=1))
# Out:
# {
#  "today": "Interview date",
#  "country": "Country",
#  "region_comparable": "Comparable regions",
#  "up_region": "Country (Ghana) / District (CdI)",
#  "region": "Region",
#  "sub_region": "District (Ghana) / Departement (Cdi)",
#  "village": "Village",
#  "latitude": "Latitude",
#  "longitude": "Longitude",
#  "consent_yn": "Consent to participate",
#  "hhmem_number": "Number of household members living in the compound",
#  "male_adults_over_65": "Number of males over 65 years old",
#  "female_adults_over_65": "Number of females over 65 years old",
#  "male_adults_15_65": "Number of males 15-65",
#  "female_adults_15_65": "Number of females between 15 and 65 years old",
#  "male_children_5_14": "Number of boys between 15 and 65 years old",
#  "female_children_5_14": "Number of girls  between 5 and 14 years old",
#  "male_children_0_4": "Number of boys younger than 4 years old",
#  "female_children_0_4": "Number of girls younger than 4 years old",
# ...

# %% [markdown]
# The full dataset has (too) many features (1252), in comparison to the number of observations.
#
# This includes features which are not useful for the analysis, and some are sets of dummy variables (which is fine).
#
# I will initially drop features that I know I will not be needing for any of the analysis.
#
# They include:
# - location variables, except country. Analysis will be on a country level
# - consent indicator, as this should be 'yes' for all observations included in this dataset
# - instanceid, unique identifier
# - data on the respondent (data on the head of the household and on the full household will suffice)
# - variables in imputed values ("fm_"), since the imputation was done based on the country level, and I will do this by other
# subgroups
# - variables with the profit and value of production, since these will be re-calculated here
# - details on the price, since only the common price per kg in USD will be used
# - indicator of selling crops for the subset of those that produced: this variable carries by construction many missing values (those that did not produce) and therefore is not of interest
# - variables with daily rates for hired labour, since the original reports refer they used median hiring cost to adjust for noise in the responses
# - question on the "(days)known" for labour activities or other, since these are intermediary variables to filter on the amount of days and therefore not needed for this analysis
# - land unit preference, since all is already converted into ha
# - cocoa_certification_yn, since there is already a cocoa_certification_clean_yn which is a better version

# %% [markdown]
# Confirm `consent` is `yes` for all observations

# %%
data['consent_yn'].value_counts()
# Out:
# yes    3045
# Name: consent_yn, dtype: int64

# %% [markdown]
# Drop variables as explained above:

# %%
data.drop(['region_comparable', 'up_region', 'sub_region', 'village', 'latitude', 'longitude'], axis = 1, inplace = True) 
data.drop(['today','consent_yn', 'instanceid', 'land_unit_preference'], axis = 1, inplace = True)
data.drop(list(data.filter(regex = 'p1_')), axis = 1, inplace = True) 
data.drop(['age_cat', 'leader','cocoa_prodgroup_respondent'], axis = 1, inplace = True) 
data.drop(list(data.filter(regex = 'fm_')), axis = 1, inplace = True) 
data.drop(['cocoa_price_common_usdkg','cocoa_price_highest_usdkg','cocoa_price_lowest_usdkg'], axis = 1, inplace = True) 
data.drop(['cocoa_valueproduction_usd','cocoa_valueproduction_usd_ha','cocoa_profit1_usdha','cocoa_profit2_usdha'], axis = 1, inplace = True) 
data.drop(list(data.filter(regex = 'crops_sold_ifprod')), axis = 1, inplace = True) 
data.drop(list(data.filter(regex = 'orig_hi_cost')), axis = 1, inplace = True)
data.drop(list(data.filter(regex = 'cocoa_marketing_income_yn')), axis = 1, inplace = True) 
data.drop(list(data.filter(regex = 'days_known_yn')), axis = 1, inplace = True) 
data.drop(['cocoa_certification_yn'], axis = 1, inplace = True)

# %% [markdown]
# For each production activity there is also two sex of workers indicators (`_gender_1, _gender_2`), plus a combined indicator (`_gender`). I can drop the later.

# %%
list(data.filter(regex = 'gender'))
# Out:
# ['head_gender',
#  'cocoa_landclear_gender_1',
#  'cocoa_landclear_gender_2',
#  'cocoa_landclear_gender',
#  'cocoa_landprep_gender_1',
#  'cocoa_landprep_gender_2',
#  'cocoa_landprep_gender',
#  'cocoa_planting_gender_1',
#  'cocoa_planting_gender_2',
#  'cocoa_planting_gender',
#  'cocoa_gfert_gender_1',
#  'cocoa_gfert_gender_2',
#  'cocoa_gfert_gender',
#  'cocoa_lfert_gender_1',
#  'cocoa_lfert_gender_2',
#  'cocoa_lfert_gender',
#  'cocoa_manurecomp_gender_1',
#  'cocoa_manurecomp_gender_2',
#  'cocoa_manurecomp_gender',
#  'cocoa_herb_gender_1',
#  'cocoa_herb_gender_2',
#  'cocoa_herb_gender',
#  'cocoa_pest_gender_1',
#  'cocoa_pest_gender_2',
#  'cocoa_pest_gender',
#  'cocoa_fung_gender_1',
#  'cocoa_fung_gender_2',
#  'cocoa_fung_gender',
#  'cocoa_weed_gender_1',
#  'cocoa_weed_gender_2',
#  'cocoa_weed_gender',
#  'cocoa_pruning_gender_1',
#  'cocoa_pruning_gender_2',
#  'cocoa_pruning_gender',
#  'cocoa_harvest_gender_1',
#  'cocoa_harvest_gender_2',
# ...

# %%
data.drop([
 'cocoa_landclear_gender',
 'cocoa_landprep_gender',
 'cocoa_planting_gender',
 'cocoa_gfert_gender',
 'cocoa_lfert_gender',
 'cocoa_manurecomp_gender',
 'cocoa_herb_gender',
 'cocoa_pest_gender',
 'cocoa_fung_gender',
 'cocoa_weed_gender',
 'cocoa_pruning_gender',
 'cocoa_harvest_gender',
 'cocoa_podbreak_gender',
 'cocoa_ferment_gender',
 'cocoa_transport_gender',
 'cocoa_decisions_gender',
 'cocoa_marketing_gender'
], axis = 1, inplace = True)

# %% [markdown]
# Similarly, for each production activity there is also four types of workers indicators (`hhhiredcom_`), plus a combined indicator (`hh_hi`). I can drop the latter.

# %%
data.drop(list(data.filter(regex = 'hh_hi')), axis = 1, inplace = True)

# %% [markdown]
# There are 3 sets of features about the allocation of production: in kg, in kg/ha and as share of total. I'll keep only the one on shares.

# %%
data.drop([
 'cocoa_sold_kg',
 'cocoa_sold_kgha',
 'cocoa_consumed_kg',
 'cocoa_consumed_kgha',
 'cocoa_oblig_kg',
 'cocoa_oblig_kgha',
 'cocoa_givenaway_kg',
 'cocoa_givenaway_kgha',
 'cocoa_barterexchange_kg',
 'cocoa_barterexchange_kgha',
 'cocoa_givenforlabour_kg',
 'cocoa_givenforlabour_kgha',
 'cocoa_lost_kg',
 'cocoa_lost_kgha'
], axis = 1, inplace = True)

# %% [markdown]
# For the analysis, I will only look at cocoa households that know their land and production

# %%
data = data[data['cocoa_hh']=='yes']
data = data[data['cocoa_land_known_yn']=='yes']
data = data[data['cocoa_prod_known_yn']=='yes']

# %%
data = data[data['cocoa_prod_total_kgsha'].notnull()]

# %%
data.drop(['cocoa_hh', 'cocoa_land_known_yn','cocoa_prod_known_yn'], axis = 1, inplace = True)

# %% [markdown]
# Further, for this analysis, I'm only interested in the total production over an year, and not disaggregated into seasons

# %%
data.drop([
    'cocoa_season1_start',
    'cocoa_season1_end',
    'cocoa_season2_start',
    'cocoa_season2_end',
    'cocoa_prod_season1_kg',
    'cocoa_prod_season1_kgha',
    'cocoa_prod_season2_kg',
    'cocoa_prod_season2_kgha'
], axis = 1, inplace = True)

# %% [markdown]
# Now I can also drop some of the other household type indicators, since I am only looking at cocoa households

# %%
list(data.filter(regex = '_hh'))
# Out:
# ['coconut_hh',
#  'cocoyam_hh',
#  'coffee_hh',
#  'courgette_hh',
#  'cotton_hh',
#  'cow_pea_hh',
#  'eggplant_hh',
#  'fodder_hh',
#  'garlic_hh',
#  'ginger_hh',
#  'groundnuts_hh',
#  'lemon_hh',
#  'lime_hh',
#  'maize_hh',
#  'mango_hh',
#  'millet_hh',
#  'okra_hh',
#  'onions_hh',
#  'oranges_hh',
#  'palm_hh',
#  'papaya_hh',
#  'peas_hh',
#  'peppers_hh',
#  'pineapple_hh',
#  'plantai_hh',
#  'irish_potato_hh',
#  'sweet_potato_hh',
#  'rice_hh',
#  'rubber_hh',
#  'spinach_hh',
#  'sorghum_hh',
#  'shea_nut_hh',
#  'sugar_cane_hh',
#  'tangerine_hh',
#  'tomatoes_hh',
#  'watermelon_hh',
#  'yam_hh',
#  'avocado_hh_5ago',
#  'bananas_hh_5ago',
#  'soya_beans_hh_5ago',
#  'beans_hh_5ago',
#  'cabbages_hh_5ago',
#  'carrots_hh_5ago',
#  'cashews_hh_5ago',
#  'cassava_hh_5ago',
#  'chili_hh_5ago',
#  'cocoa_hh_5ago',
#  'coconut_hh_5ago',
#  'cocoyam_hh_5ago',
#  'coffee_hh_5ago',
#  'courgette_hh_5ago',
#  'cotton_hh_5ago',
#  'cow_pea_hh_5ago',
#  'eggplant_hh_5ago',
# ...

# %%
data.drop(
['coconut_hh',
 'cocoyam_hh',
 'coffee_hh',
 'courgette_hh',
 'cotton_hh',
 'cow_pea_hh',
 'eggplant_hh',
 'fodder_hh',
 'garlic_hh',
 'ginger_hh',
 'groundnuts_hh',
 'lemon_hh',
 'lime_hh',
 'maize_hh',
 'mango_hh',
 'millet_hh',
 'okra_hh',
 'onions_hh',
 'oranges_hh',
 'palm_hh',
 'papaya_hh',
 'peas_hh',
 'peppers_hh',
 'pineapple_hh',
 'plantai_hh',
 'irish_potato_hh',
 'sweet_potato_hh',
 'rice_hh',
 'rubber_hh',
 'spinach_hh',
 'sorghum_hh',
 'shea_nut_hh',
 'sugar_cane_hh',
 'tangerine_hh',
 'tomatoes_hh',
 'watermelon_hh',
 'yam_hh',
 'avocado_hh_5ago',
 'bananas_hh_5ago',
 'soya_beans_hh_5ago',
 'beans_hh_5ago',
 'cabbages_hh_5ago',
 'carrots_hh_5ago',
 'cashews_hh_5ago',
 'cassava_hh_5ago',
 'chili_hh_5ago',
 'cocoa_hh_5ago',
 'coconut_hh_5ago',
 'cocoyam_hh_5ago',
 'coffee_hh_5ago',
 'courgette_hh_5ago',
 'cotton_hh_5ago',
 'cow_pea_hh_5ago',
 'eggplant_hh_5ago',
 'fodder_hh_5ago',
 'garlic_hh_5ago',
 'ginger_hh_5ago',
 'groundnuts_hh_5ago',
 'lemon_hh_5ago',
 'lime_hh_5ago',
 'maize_hh_5ago',
 'mango_hh_5ago',
 'millet_hh_5ago',
 'okra_hh_5ago',
 'onions_hh_5ago',
 'oranges_hh_5ago',
 'palm_hh_5ago',
 'papaya_hh_5ago',
 'peas_hh_5ago',
 'peppers_hh_5ago',
 'pineapple_hh_5ago',
 'plantai_hh_5ago',
 'irish_potato_hh_5ago',
 'sweet_potato_hh_5ago',
 'rice_hh_5ago',
 'rubber_hh_5ago',
 'spinach_hh_5ago',
 'sorghum_hh_5ago',
 'shea_nut_hh_5ago',
 'sugar_cane_hh_5ago',
 'tangerine_hh_5ago',
 'tomatoes_hh_5ago',
 'watermelon_hh_5ago',
 'yam_hh_5ago',
 'avocado_hh_change',
 'bananas_hh_change',
 'soya_beans_hh_change',
 'beans_hh_change',
 'cabbages_hh_change',
 'carrots_hh_change',
 'cashews_hh_change',
 'cassava_hh_change',
 'chili_hh_change',
 'cocoa_hh_change',
 'coconut_hh_change',
 'cocoyam_hh_change',
 'coffee_hh_change',
 'courgette_hh_change',
 'cotton_hh_change',
 'cow_pea_hh_change',
 'eggplant_hh_change',
 'fodder_hh_change',
 'garlic_hh_change',
 'ginger_hh_change',
 'groundnuts_hh_change',
 'lemon_hh_change',
 'lime_hh_change',
 'maize_hh_change',
 'mango_hh_change',
 'millet_hh_change',
 'okra_hh_change',
 'onions_hh_change',
 'oranges_hh_change',
 'palm_hh_change',
 'papaya_hh_change',
 'peas_hh_change',
 'peppers_hh_change',
 'pineapple_hh_change',
 'plantai_hh_change',
 'irish_potato_hh_change',
 'sweet_potato_hh_change',
 'rice_hh_change',
 'rubber_hh_change',
 'spinach_hh_change',
 'sorghum_hh_change',
 'shea_nut_hh_change',
 'sugar_cane_hh_change',
 'tangerine_hh_change',
 'tomatoes_hh_change',
 'watermelon_hh_change',
 'yam_hh_change']
, axis = 1, inplace = True)

# %%
print("Shape of data set:", data.shape)
# Out:
# Shape of data set: (1455, 871)

# %% [markdown]
# Check the distribution across countries:

# %%
data['country'].value_counts()
# Out:
# Ghana    1008
# CdI       447
# Name: country, dtype: int64

# %% [markdown]
# ## 0.3 Analytical Groups

# %% [markdown]
# In line with the Gap Analysis studies ([here](https://c69aa8ac-6965-42b2-abb7-0f0b86c23d2e.filesusr.com/ugd/0c5ab3_fc3386a550b94a898c7757ee13ab59e6.pdf) and [here](https://c69aa8ac-6965-42b2-abb7-0f0b86c23d2e.filesusr.com/ugd/0c5ab3_93560a9b816d40c3a28daaa686e972a5.pdf)), I will create 3 groups per country:
#
# * Female-headed
# * Male-headed, typical: Productive cocoa land up to 4 ha
# * Male-headed, large: Productive cocoa land larger than  4ha

# %%
data.loc[(data['head_gender'] == 'female') & (data['country'] == 'Ghana') , 'Analytical Group'] = 'Ghana: Female-headed'
data.loc[(data['head_gender'] == 'male'  ) & (data['country'] == 'Ghana') & (data['cocoa_land_used_morethan5_ha']<=4), 'Analytical Group'] = 'Ghana: Male-headed, typical'
data.loc[(data['head_gender'] == 'male'  ) & (data['country'] == 'Ghana') & (data['cocoa_land_used_morethan5_ha']>4 ), 'Analytical Group'] = 'Ghana: Male-headed, large'

data.loc[(data['head_gender'] == 'female') & (data['country'] == 'CdI' ) , 'Analytical Group'] = 'CdI: Female-headed'
data.loc[(data['head_gender'] == 'male'  ) & (data['country'] == 'CdI' ) & (data['cocoa_land_used_morethan5_ha']<=4), 'Analytical Group'] = 'CdI: Male-headed, typical'
data.loc[(data['head_gender'] == 'male'  ) & (data['country'] == 'CdI' ) & (data['cocoa_land_used_morethan5_ha']>4 ), 'Analytical Group'] = 'CdI: Male-headed, large'

# %% [markdown]
# Check:

# %%
data['Analytical Group'].value_counts()
# Out:
# Ghana: Male-headed, typical    627
# CdI: Male-headed, typical      313
# Ghana: Male-headed, large      219
# Ghana: Female-headed           162
# CdI: Male-headed, large        119
# CdI: Female-headed              15
# Name: Analytical Group, dtype: int64

# %% [markdown]
# Because the group `CdI: Female-headed` is too small ( _N = 15_ ) I will remove it from the analysis

# %%
data = data[data['Analytical Group']!='CdI: Female-headed']

# %% [markdown]
# # 1. Calculating the total income

# %% [markdown]
# ## 1.1 Introduction

# %% [markdown]
# We calculate the total household income as:
#
# _Total Household Income = (net cocoa income)/(income share from cocoa)_
#
# In other words, I calculate the net cocoa income, and extrapolate the household income by using the information on the share of total income coming from cocoa
#
# Te _net cocoa income_ is calculated as:
#
# _net cocoa income = (total production (kg/ha) * price (USD/kg) - input costs (USD/ha) - labor costs (USD/ha))* Productive land (ha)_
#
# To calculate input costs and labor costs I need to go over the different input types and production activities

# %% [markdown]
# ## 1.2 Calculating income components

# %% [markdown]
# The detailed cocoa production features are built over a few production activities, types of labor and inputs. I will create lists with those activities, types of labor and inputs for further iteration in this notebook.

# %%
production_activities = [
    'landclear',
    'landprep',
    'planting',
    'gfert',
    'lfert',
    'manurecomp',
    'herb',
    'pest',
    'fung',
    'weed',
    'pruning',
    'harvest',
    'podbreak',
    'ferment',
    'transport',
    'dry'
]

types_of_labor = [
    'hi_n_ha',
    'hh_n_ha',
    'com_n_ha',
    'lab_n_ha',
    'hi_lab_usdha'
]

inputs = [
    'gfert',
    'lfert',
    'herb',
    'pest',
    'fung'
]

# %% [markdown]
# Let's first check if these variables have missing values. I look at the `hi_lab_usdha` features, since this is directly relevant for the calculations:

# %%
data.filter(regex = 'hi_lab_usdha').describe()
# Out:
#        cocoa_landclear_hi_lab_usdha  cocoa_landprep_hi_lab_usdha  \
# count                   1214.000000                  1177.000000
# mean                       4.767475                     1.937751
# std                       14.252392                    10.797347
# min                        0.000000                     0.000000
# 25%                        0.000000                     0.000000
# 50%                        0.000000                     0.000000
# 75%                        0.000000                     0.000000
# max                      129.067871                   160.617813
#
#        cocoa_planting_hi_lab_usdha  cocoa_gfert_hi_lab_usdha  \
# count                   848.000000               1063.000000
# mean                      1.512468                  1.013818
# std                       7.526684                  4.708277
# min                       0.000000                  0.000000
# 25%                       0.000000                  0.000000
# ...

# %% [markdown]
# As expected these features have missing values, in different levels. As the previous studies explain, this happens when farmers know they did some activity, but did not know the exact costs.
#
# Let's verify:

# %%
data.loc[data['cocoa_landclear_hi_lab_usdha'].isnull(),'cocoa_landclear_yn'].value_counts()
# Out:
# yes    221
# no       5
# Name: cocoa_landclear_yn, dtype: int64

# %% [markdown]
# My strategy will be to:
#
# - enforce 0 if activity was not done
# - if the activity was done but it is missing, fill the missing values with the median values (per ha) of the farmers that did the activity and could specify the costs. I will do this per analytical group.

# %%
def fill_na_by_group(df, yn_feature, feature, group_feature, strategy = 'median'):
    '''
    fills missing values in given feature with the group median (default) or mean value
        
    
    INPUT:
        df: panda DataFrame
        yn_feature: colname to be used to slice the dataframe into doing (yes) or not doing (no) an activity
        feature: colname to be filled
        group_feature: feature identifying the different groups
        strategy = 'median' or 'mean'
        
    OUTPUT:
        df: modified DataFrame
    '''
    
    # first enforce 0 if yn_feature = 'no'
    df.loc[df[yn_feature]=='no', feature] = 0

    # get a list of groups
    groups = df[group_feature].unique()
    
    # for each group, filter on yn_feature = yes and fill in median
    for group in groups:
        
        if strategy == 'median':
            fill_value = df.loc[(df[group_feature] == group) & (df[yn_feature] == 'yes'), feature ].median()
        elif strategy == 'mean':
            fill_value = df.loc[(df[group_feature] == group) & (df[yn_feature] == 'yes'), feature ].mean()
        else:
            raise SyntaxError('Strategy unknown')
        
        df.loc[(df[group_feature] == group) & (df[yn_feature] == 'yes'), feature ] = df.loc[(df[group_feature] == group) & (df[yn_feature] == 'yes'), feature ].fillna(fill_value)
       
    
    # return modified DataFrame
    return df

# %%
# iterate through all types of labor
for labor_type in types_of_labor:
    
    # find all columns with that labor type
    full_list = list(data.filter(regex = labor_type))
    
    # apply the fill_na_by_group to each of these columns
    for col in full_list:
        yn_feature = col.replace(labor_type,'yn')
        data = fill_na_by_group(data, yn_feature, col, 'Analytical Group')
# Out:
# C:\Users\marce\anaconda3\envs\livingincomemodel\lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# Check to be sure it worked as expected:

# %%
data.filter(regex = 'hi_lab_usdha').describe()
# Out:
#        cocoa_landclear_hi_lab_usdha  cocoa_landprep_hi_lab_usdha  \
# count                   1440.000000                  1440.000000
# mean                       6.023580                     1.798956
# std                       13.587464                     9.865636
# min                        0.000000                     0.000000
# 25%                        0.000000                     0.000000
# 50%                        0.000000                     0.000000
# 75%                        7.407631                     0.000000
# max                      129.067871                   160.617813
#
#        cocoa_planting_hi_lab_usdha  cocoa_gfert_hi_lab_usdha  \
# count                  1440.000000               1440.000000
# mean                      0.890675                  0.748395
# std                       5.822297                  4.069268
# min                       0.000000                  0.000000
# 25%                       0.000000                  0.000000
# ...

# %% [markdown]
# I can now calculate the total hired labor costs

# %%
data['Cocoa hired labour costs (USD/ha)'] = data.filter(regex = 'hi_lab_usdha').sum(axis = 1)

# %% [markdown]
# I use a similar strategy for the input costs:

# %%
inputcosts_extended_list = ['cocoa_' + this_input + '_usdha' for this_input in inputs]
data[inputcosts_extended_list].describe()
# Out:
#        cocoa_gfert_usdha  cocoa_lfert_usdha  cocoa_herb_usdha  \
# count        1416.000000        1405.000000       1363.000000
# mean            8.633908           2.848810          7.123006
# std            35.850754           9.368061         11.274248
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.000000
# 75%             0.000000           0.000000         12.019188
# max           464.644409          77.440727         67.115295
#
#        cocoa_pest_usdha  cocoa_fung_usdha
# count       1348.000000       1369.000000
# mean          17.830339          2.592730
# std           22.563570          6.736536
# min            0.000000          0.000000
# 25%            0.000000          0.000000
# 50%           10.755658          0.000000
# 75%           25.813578          0.000000
# max          136.660110         53.119999

# %%
# iterate through all input costs
for col in inputcosts_extended_list:
    yn_feature = col.replace("usdha",'yn')
    data = fill_na_by_group(data, yn_feature, col, 'Analytical Group')

# %% [markdown]
# Check

# %%
data[inputcosts_extended_list].describe()
# Out:
#        cocoa_gfert_usdha  cocoa_lfert_usdha  cocoa_herb_usdha  \
# count        1440.000000        1440.000000       1440.000000
# mean            8.719258           2.798435          7.551852
# std            35.630737           9.273262         11.145161
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.000000
# 75%             0.000000           0.000000         13.552127
# max           464.644409          77.440727         67.115295
#
#        cocoa_pest_usdha  cocoa_fung_usdha
# count       1440.000000       1440.000000
# mean          17.669802          2.471631
# std           21.843737          6.591332
# min            0.000000          0.000000
# 25%            0.000000          0.000000
# 50%           12.177862          0.000000
# 75%           24.879286          0.000000
# max          136.660110         53.119999

# %% [markdown]
# Now I can also calculate the total input costs:

# %%
data['Cocoa input costs (USD/ha)'] = data[inputcosts_extended_list].sum(axis = 1)

# %% [markdown]
# ## 1.3 Value adjustments over time

# %% [markdown]
# Since a main goal of this analysis is to compare total incomes with the Living Income Benchmark value, they need to be comparable in purchasing power. The Living Income Benchmark values refer to Q1 2018 (Ghana) and Q2 2018 (Côte d'Ivoire). This data, on the other hand, refers to Q1 2016. Therefore I will use a [CPI correction factor](http://data.imf.org/regular.aspx?key=61545849) to bring the survey data from 2016 to 2018 values

# %%
# CPI Correction

# Ghana CPI in 2018 Q1: 247.05
# Ghana CPI in 2016 Q1: 197.77
# Living Income  CEDI to USD = 1/4.45 // March 1st 2018
# Survey data CEDI to USD = 0.26116 // Jan 15th, 2016
correction_factor_ghana = (1/0.26116)/197.77*247.05/4.45


# CdI CPI in 2018 Q2: 112.92
# CdI CPI in 2016 Q1: 111.35
# Living Income CFA to USD = 1/576.81 // August 2018
# Survey data CFA to USD = 0.00166 // Jan 16th, 2016
correction_factor_cdi = (1/0.00166)/111.35*112.92/576.81

# %% [markdown]
# Apply the correction factor all variables in USD:

# %%
usd_list = data.filter(regex = "usd").columns
usd_list = usd_list.append(data.filter(regex = "USD").columns)

# %%
data.loc[data['country'] == 'Ghana', usd_list] = data.loc[data['country'] == 'Ghana', usd_list]*correction_factor_ghana
data.loc[data['country'] == 'CdI', usd_list] = data.loc[data['country'] == 'CdI', usd_list]*correction_factor_cdi

# %% [markdown]
# ## 1.4 Total household income estimation

# %% [markdown]
# Finally I will check if all households have estimated share of income coming from cocoa:

# %%
data['hh_income_perc_cocoa'].describe()
# Out:
# count    1438.000000
# mean        0.628804
# std         0.214800
# min         0.000000
# 25%         0.500000
# 50%         0.600000
# 75%         0.800000
# max         1.000000
# Name: hh_income_perc_cocoa, dtype: float64

# %%
data['hh_income_perc_cocoa'].isnull().sum()
# Out:
# 2

# %% [markdown]
# I will also fill these missing values with the group median

# %%
data['temp']='yes'
data = fill_na_by_group(data,'temp', 'hh_income_perc_cocoa', 'Analytical Group')
data.drop('temp', axis = 1, inplace = True)

# %% [markdown]
# I also need to drop observations where the share is 0%

# %%
data = data[data['hh_income_perc_cocoa']>0]

# %% [markdown]
# Now I can compute total household income:

# %%
data['Estimated total household income (USD/household/year)'] = (
    (
        + data['cocoa_prod_total_kgsha']*data['cocoa_price_usdkg'] 
        - data['Cocoa input costs (USD/ha)']
        - data['Cocoa hired labour costs (USD/ha)']
    )*data['cocoa_land_used_morethan5_ha'] 
    /data['hh_income_perc_cocoa']
)

# %% [markdown]
# Let's check:

# %%
data['Estimated total household income (USD/household/year)'].describe()
# Out:
# count     1434.000000
# mean      3165.161133
# std       3846.371094
# min     -16244.933594
# 25%        989.524460
# 50%       2002.150330
# 75%       3960.125427
# max      49948.113281
# Name: Estimated total household income (USD/household/year), dtype: float64

# %% [markdown]
# Let's drop observations where the total household income is smaller than 0 (likely due to erros in the other variables)

# %%
data = data[data['Estimated total household income (USD/household/year)']>0]

# %% [markdown]
# Let's also drop observations that have income values more than 4 standard deviations above the mean, in a iterative loop

# %%
upper_limit = data['Estimated total household income (USD/household/year)'].mean() + data['Estimated total household income (USD/household/year)'].std()*4

while data['Estimated total household income (USD/household/year)'].max() > upper_limit:
    data = data[data['Estimated total household income (USD/household/year)']<=upper_limit]
    upper_limit = data['Estimated total household income (USD/household/year)'].mean() + data['Estimated total household income (USD/household/year)'].std()*4

# %% [markdown]
# ## 1.5 Exploration of total household income

# %% [markdown]
# Let's check basic descriptives:

# %%
data.groupby('country')['Estimated total household income (USD/household/year)'].describe()
# Out:
#          count         mean          std        min          25%          50%  \
# country
# Ghana    970.0  2821.448242  2594.180908  15.572671  1052.486908  1910.728027
# CdI      407.0  2978.242920  2723.839600  18.753250   996.925751  2158.178467
#
#                  75%           max
# country
# Ghana    3773.894104  13381.899414
# CdI      3966.554443  13298.229492

# %%
data.groupby('Analytical Group')['Estimated total household income (USD/household/year)'].describe()
# Out:
#                              count         mean          std         min  \
# Analytical Group
# CdI: Male-headed, large      101.0  5046.210449  3238.920166  387.704834
# CdI: Male-headed, typical    306.0  2295.678467  2133.793213   18.753250
# Ghana: Female-headed         150.0  1679.433350  1760.737549   15.572671
# Ghana: Male-headed, large    204.0  5280.250000  3382.007568  281.954163
# Ghana: Male-headed, typical  616.0  2285.258057  1861.575684   68.563194
#
#                                      25%          50%          75%  \
# Analytical Group
# CdI: Male-headed, large      2573.553955  4286.904785  7436.996094
# CdI: Male-headed, typical     855.932037  1751.853882  2847.878174
# Ghana: Female-headed          534.136780  1039.841949  2080.295502
# Ghana: Male-headed, large    2531.117065  4748.681641  7601.145386
# Ghana: Male-headed, typical  1052.614532  1721.023865  2985.473633
#
#                                       max
# Analytical Group
# ...

# %% [markdown]
# Lets plot some histograms:

# %%
plt.figure(figsize=(10,10))
plt.title ('Ditribution of incomes')
sns.distplot(data['Estimated total household income (USD/household/year)']);
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\1456978396.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Estimated total household income (USD/household/year)']);

# %%
plt.figure(figsize=(10,10))
plt.title ('Ditribution of incomes per country')
sns.kdeplot(data[data['country']=='Ghana']['Estimated total household income (USD/household/year)'],  shade=True , label = 'Ghana');
sns.kdeplot(data[data['country']=='CdI']['Estimated total household income (USD/household/year)'], shade = True, label = 'Côte d\'Ivoire');
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\3517392132.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['country']=='Ghana']['Estimated total household income (USD/household/year)'],  shade=True , label = 'Ghana');
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\3517392132.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['country']=='CdI']['Estimated total household income (USD/household/year)'], shade = True, label = 'Côte d\'Ivoire');

# %%
plt.figure(figsize=(10,10))
plt.title ('Ditribution of incomes in Ghana')
plt.xlabel("Household Annual Income (USD)")
sns.kdeplot(data[data['Analytical Group']=='Ghana: Female-headed']['Estimated total household income (USD/household/year)'], shade = True, label = 'Female-headed');
sns.kdeplot(data[data['Analytical Group']=='Ghana: Male-headed, typical']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, typical')
sns.kdeplot(data[data['Analytical Group']=='Ghana: Male-headed, large']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, large');
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\1212231680.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['Analytical Group']=='Ghana: Female-headed']['Estimated total household income (USD/household/year)'], shade = True, label = 'Female-headed');
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\1212231680.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['Analytical Group']=='Ghana: Male-headed, typical']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, typical')
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\1212231680.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
plt.figure(figsize=(10,10))
plt.title ('Ditribution of incomes in Cotê d\'Ivoire')
plt.xlabel("Household Annual Income (USD)")
sns.kdeplot(data[data['Analytical Group']=='CdI: Male-headed, typical']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, typical')
sns.kdeplot(data[data['Analytical Group']=='CdI: Male-headed, large']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, large');
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\4030847551.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['Analytical Group']=='CdI: Male-headed, typical']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, typical')
# C:\Users\marce\AppData\Local\Temp\ipykernel_105880\4030847551.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[data['Analytical Group']=='CdI: Male-headed, large']['Estimated total household income (USD/household/year)'], shade = True, label = 'Male-headed, large');

# %% [markdown]
# # 2 Living Income Benchmark

# %% [markdown]
# I will create a feature including the living benchmark value and an indicator variable for achieving it. These values can be found  [here](https://c69aa8ac-6965-42b2-abb7-0f0b86c23d2e.filesusr.com/ugd/0c5ab3_fc3386a550b94a898c7757ee13ab59e6.pdf) and [here](https://c69aa8ac-6965-42b2-abb7-0f0b86c23d2e.filesusr.com/ugd/0c5ab3_93560a9b816d40c3a28daaa686e972a5.pdf)

# %%
data.loc[data['country']=='CdI','Living Income Benchmark'] = 6518
data.loc[data['Analytical Group']=='Ghana: Female-headed','Living Income Benchmark'] = 4001
data.loc[data['Analytical Group']=='Ghana: Male-headed, typical','Living Income Benchmark'] = 4742
data.loc[data['Analytical Group']=='Ghana: Male-headed, large','Living Income Benchmark'] = 5123

data.groupby('Analytical Group')['Living Income Benchmark'].describe()
# Out:
#                              count    mean  std     min     25%     50%  \
# Analytical Group
# CdI: Male-headed, large      101.0  6518.0  0.0  6518.0  6518.0  6518.0
# CdI: Male-headed, typical    306.0  6518.0  0.0  6518.0  6518.0  6518.0
# Ghana: Female-headed         150.0  4001.0  0.0  4001.0  4001.0  4001.0
# Ghana: Male-headed, large    204.0  5123.0  0.0  5123.0  5123.0  5123.0
# Ghana: Male-headed, typical  616.0  4742.0  0.0  4742.0  4742.0  4742.0
#
#                                 75%     max
# Analytical Group
# CdI: Male-headed, large      6518.0  6518.0
# CdI: Male-headed, typical    6518.0  6518.0
# Ghana: Female-headed         4001.0  4001.0
# Ghana: Male-headed, large    5123.0  5123.0
# Ghana: Male-headed, typical  4742.0  4742.0

# %% [markdown]
# Create the indicator

# %%
data['Living Income Achieved'] = data['Estimated total household income (USD/household/year)']>= data['Living Income Benchmark']

# %% [markdown]
# ## QUESTION 1: How many farming households achieve a living Income?

# %%
print("{0}% reach a living income".format(round(data['Living Income Achieved'].mean()*100)))
# Out:
# 15% reach a living income

# %% [markdown]
# Is quite confronting to realize that only this amount of farmers producing cocoa reach a living income

# %% [markdown]
# ## QUESTION 2: Is there a difference per group?

# %%
summary = data.groupby('Analytical Group')['Living Income Achieved'].mean()*100

# %%
summary
# Out:
# Analytical Group
# CdI: Male-headed, large        27.722772
# CdI: Male-headed, typical       6.535948
# Ghana: Female-headed            9.333333
# Ghana: Male-headed, large      42.647059
# Ghana: Male-headed, typical     9.090909
# Name: Living Income Achieved, dtype: float64

# %% [markdown]
# Let's make a graph per group:

# %%
plt.figure(figsize=(10,10))
plt.ylabel("Percentage farming households reaching a living income")
plt.title("How many farmers reach a living income by group? (red line shows overall mean)")
ax = summary.plot.bar(yticks = range(0,110,10));
ax.axhline(y=round(data['Living Income Achieved'].mean()*100),
              color='r', linestyle='--', lw=2, label = "abc");

# %% [markdown]
# There is clearly a difference per group. Households with larger farms are much more likely to reach a living income

# %% [markdown]
# ## QUESTION 3: What is the gap of median household (per group)?

# %% [markdown]
# Let's create a summary dataframe with the median values:

# %%
summary_median = data.groupby('Analytical Group')[
    ['Estimated total household income (USD/household/year)', 'Living Income Benchmark']
].median()

# %%
summary_median['Income Share'] = summary_median['Estimated total household income (USD/household/year)']/summary_median['Living Income Benchmark']*100
summary_median['Gap Share'] = 100 - summary_median['Income Share']

# %%
summary_median
# Out:
#                              Estimated total household income (USD/household/year)  \
# Analytical Group
# CdI: Male-headed, large                                            4286.904785
# CdI: Male-headed, typical                                          1751.853882
# Ghana: Female-headed                                               1039.841919
# Ghana: Male-headed, large                                          4748.681641
# Ghana: Male-headed, typical                                        1721.023926
#
#                              Living Income Benchmark  Income Share  Gap Share
# Analytical Group
# CdI: Male-headed, large                       6518.0     65.770248  34.229752
# CdI: Male-headed, typical                     6518.0     26.877169  73.122831
# Ghana: Female-headed                          4001.0     25.989551  74.010449
# Ghana: Male-headed, large                     5123.0     92.693376   7.306624
# ...

# %% [markdown]
# Let's visualize this as stacked bar chart:

# %%
summary_median[['Income Share', 'Gap Share']].plot.bar(stacked=True, figsize=(10,10),
                                                      ylabel ="Percentage of the Living Income benchmark",
                                                      yticks = range(0,110,10)
                                                      );

# %% [markdown]
# I can see that there is a similar difference per group, but even the group that mostly reach the living income, there is still a gap of 7% in the median household.

# %% [markdown]
# # 3 Prepare for Machine Learning

# %% [markdown]
# Now I want to buld a classifier that will predict if a farming household reaches or not the Living Income Benchmark.
#
# The goal here is to have a model with as few variablse as possible, which are likely to be either know by companies working with these farmers or relatevely easy to collect.

# %% [markdown]
# The creation of the classifier is show in [this](LivingIncome_MachineLearning.ipynb) jupyter notebook (for easiness of reading), but I'll keep the data preparation here.

# %% [markdown]
# ## 3.1 Feature Selection

# %% [markdown]
# I'll further select features by removing features that should not be used by the ML model or that have too many missing values to be used.

# %% [markdown]
# The goal is to predict if a farming household achieves the Living Income Benchmark, without knowing their total household income (if one would know the total household income, or be able to compute, there is no need for a classifier model).
#
# Therefore I'll drop all the calculated income variables I just built, plus the aggregated and detailed costs of labour and inputs. I'll keep only indicator features of activities and sex and type of labor

# %%
data.drop([
    'Cocoa hired labour costs (USD/ha)',
    'Cocoa input costs (USD/ha)',
    'Estimated total household income (USD/household/year)',
    'Living Income Benchmark',
    'cocoa_marketing_income_usd',
    'cocoa_marketing_income_usdha'
], axis = 1, inplace = True)

# %%
data.drop([
 'cocoa_landclear_hi_n_ha',
 'cocoa_landclear_hh_n_ha',
 'cocoa_landclear_com_n_ha',
 'cocoa_landclear_lab_n_ha',
 'cocoa_landclear_hi_lab_usdha',
 'cocoa_landprep_hi_n_ha',
 'cocoa_landprep_hh_n_ha',
 'cocoa_landprep_com_n_ha',
 'cocoa_landprep_lab_n_ha',
 'cocoa_landprep_hi_lab_usdha',
 'cocoa_planting_hi_n_ha',
 'cocoa_planting_hh_n_ha',
 'cocoa_planting_com_n_ha',
 'cocoa_planting_lab_n_ha',
 'cocoa_planting_hi_lab_usdha',
 'cocoa_gfert_hi_n_ha',
 'cocoa_gfert_hh_n_ha',
 'cocoa_gfert_com_n_ha',
 'cocoa_gfert_lab_n_ha',
 'cocoa_gfert_hi_lab_usdha',
 'cocoa_lfert_hi_n_ha',
 'cocoa_lfert_hh_n_ha',
 'cocoa_lfert_com_n_ha',
 'cocoa_lfert_lab_n_ha',
 'cocoa_lfert_hi_lab_usdha',
 'cocoa_manurecomp_hi_n_ha',
 'cocoa_manurecomp_hh_n_ha',
 'cocoa_manurecomp_com_n_ha',
 'cocoa_manurecomp_lab_n_ha',
 'cocoa_manurecomp_hi_lab_usdha',
 'cocoa_herb_hi_n_ha',
 'cocoa_herb_hh_n_ha',
 'cocoa_herb_com_n_ha',
 'cocoa_herb_lab_n_ha',
 'cocoa_herb_hi_lab_usdha',
 'cocoa_pest_hi_n_ha',
 'cocoa_pest_hh_n_ha',
 'cocoa_pest_com_n_ha',
 'cocoa_pest_lab_n_ha',
 'cocoa_pest_hi_lab_usdha',
 'cocoa_fung_hi_n_ha',
 'cocoa_fung_hh_n_ha',
 'cocoa_fung_com_n_ha',
 'cocoa_fung_lab_n_ha',
 'cocoa_fung_hi_lab_usdha',
 'cocoa_weed_hi_n_ha',
 'cocoa_weed_hh_n_ha',
 'cocoa_weed_com_n_ha',
 'cocoa_weed_lab_n_ha',
 'cocoa_weed_hi_lab_usdha',
 'cocoa_pruning_hi_n_ha',
 'cocoa_pruning_hh_n_ha',
 'cocoa_pruning_com_n_ha',
 'cocoa_pruning_lab_n_ha',
 'cocoa_pruning_hi_lab_usdha',
 'cocoa_harvest_hi_n_ha',
 'cocoa_harvest_hh_n_ha',
 'cocoa_harvest_com_n_ha',
 'cocoa_harvest_lab_n_ha',
 'cocoa_harvest_hi_lab_usdha',
 'cocoa_podbreak_hi_n_ha',
 'cocoa_podbreak_hh_n_ha',
 'cocoa_podbreak_com_n_ha',
 'cocoa_podbreak_lab_n_ha',
 'cocoa_podbreak_hi_lab_usdha',
 'cocoa_transport_hi_n_ha',
 'cocoa_transport_hh_n_ha',
 'cocoa_transport_com_n_ha',
 'cocoa_transport_lab_n_ha',
 'cocoa_transport_hi_lab_usdha',
 'cocoa_landclear_times',
 'cocoa_landclear_ha',
 'cocoa_landclear_hi_cost',
 'cocoa_landprep_times',
 'cocoa_landprep_ha',
 'cocoa_landprep_how_1',
 'cocoa_landprep_how_2',
 'cocoa_landprep_how_3',
 'cocoa_landprep_how_4',
 'cocoa_landprep_hi_cost',
 'cocoa_planting_times',
 'cocoa_planting_ha',
 'cocoa_planting_hi_cost',
 'cocoa_gfert_hi_cost',
 'cocoa_gfert_times',
 'cocoa_gfert_given_yn',
 'cocoa_gfert_purchased_yn',
 'cocoa_gfert_given_pack',
 'cocoa_gfert_purchased_pack',
 'cocoa_gfert_pack_used_total',
 'cocoa_gfert_given_unitha',
 'cocoa_gfert_purchased_unitha',
 'cocoa_gfert_applied_unitha',
 'cocoa_gfert_usdha',
 'cocoa_lfert_times',
 'cocoa_lfert_given_yn',
 'cocoa_lfert_purchased_yn',
 'cocoa_lfert_given_pack',
 'cocoa_lfert_purchased_pack',
 'cocoa_lfert_pack_used_total',
 'cocoa_lfert_given_unitha',
 'cocoa_lfert_purchased_unitha',
 'cocoa_lfert_applied_unitha',
 'cocoa_lfert_usdha',
 'cocoa_lfert_hi_cost',
 'cocoa_manurecomp_times',
 'cocoa_manurecomp_hi_cost',
 'cocoa_herb_times',
 'cocoa_herb_given_yn',
 'cocoa_herb_purchased_yn',
 'cocoa_herb_given_pack',
 'cocoa_herb_purchased_pack',
 'cocoa_herb_pack_used_total',
 'cocoa_herb_given_unitha',
 'cocoa_herb_purchased_unitha',
 'cocoa_herb_applied_unitha',
 'cocoa_herb_usdha',
 'cocoa_herb_hi_cost',
 'cocoa_pest_times',
 'cocoa_pest_given_yn',
 'cocoa_pest_purchased_yn',
 'cocoa_pest_given_pack',
 'cocoa_pest_purchased_pack',
 'cocoa_pest_pack_used_total',
 'cocoa_pest_given_unitha',
 'cocoa_pest_purchased_unitha',
 'cocoa_pest_applied_unitha',
 'cocoa_pest_usdha',
 'cocoa_pest_hi_cost',
 'cocoa_fung_times',
 'cocoa_fung_given_yn',
 'cocoa_fung_purchased_yn',
 'cocoa_fung_given_pack',
 'cocoa_fung_purchased_pack',
 'cocoa_fung_pack_used_total',
 'cocoa_fung_given_unitha',
 'cocoa_fung_purchased_unitha',
 'cocoa_fung_applied_unitha',
 'cocoa_fung_usdha',
 'cocoa_fung_hi_cost',
 'cocoa_weed_times',
 'cocoa_weed_hi_cost',
 'cocoa_pruning_times',
 'cocoa_pruning_hi_cost',
 'cocoa_harvest_times',
 'cocoa_harvest_hi_cost',
 'cocoa_podbreak_times',
 'cocoa_podbreak_wait_days',
 'cocoa_podbreak_hi_cost',
 'cocoa_ferment_wait_days',
 'cocoa_ferment_material_1',
 'cocoa_ferment_material_2',
 'cocoa_ferment_material_3',
 'cocoa_ferment_material_4',
 'cocoa_ferment_material_5',
 'cocoa_ferment_material_999',
 'cocoa_ferment_material_99',
 'cocoa_transport_means',
 'cocoa_transport_times',
 'cocoa_transport_hi_cost',
 'cocoa_dry_wait_days',
 'cocoa_dry_material',
], axis = 1, inplace = True)

# %% [markdown]
# Lets also drop all `yes/no`, questions which are only filters in the survey

# %%
data.drop(list(data.filter(regex = 'known_yn')), axis = 1, inplace = True)

# %% [markdown]
# Since these are all cocoa farmers, let's drop the question on most important crop

# %% [markdown]
# Let's first check if there is indeed little variation:

# %%
data['crops_important1'].value_counts()/len(data.index)*100
# Out:
# Cocoa                   92.447349
# Cashews                  1.815541
# Rubber                   1.597676
# Palm                     1.016703
# Rice                     0.726216
# Plantain                 0.435730
# Maize                    0.290487
# Cassava                  0.290487
# Eggplant                 0.217865
# Tomatoes                 0.217865
# none/ not applicable     0.217865
# Ginger                   0.145243
# Pineapple                0.145243
# Coconut                  0.072622
# Groundnuts               0.072622
# Other                    0.072622
# Yam                      0.072622
# Coffee                   0.072622
# Chili                    0.072622
# Garlic                   0.000000
# Cabbages                 0.000000
# Peppers                  0.000000
# Cocoyam                  0.000000
# Papaya                   0.000000
# Oranges                  0.000000
# Okra                     0.000000
# Beans                    0.000000
# ...

# %%
data.drop(['crops_important1', 'crops_important1_5ago', 'crops_important2_5ago'], axis = 1, inplace = True)

# %% [markdown]
# ## 3.2 Investigate Missing values more in detail

# %% [markdown]
# I'll create a function to compute the number of missing values per variable, as a share of the total

# %%
def missing_per_variable(data, describe = True):
    '''
    computes the number of missing values per variable
        
    INPUT:
        data: panda DataFrame
        describe: print a decription table
        
    OUTPUT:
        share_missing: panda Series with the share of missing values per variables
    '''
    share_missing = data.isnull().sum()/len(data.index)*100
    
    if describe:
        print(share_missing.describe(percentiles = [.25, .5, .75, .90, .95, .99],))
    
    return share_missing

# %% [markdown]
# I'll also create a function that plots the missing values per variable:

# %%
def plot_missing(share_missing, cutoff = 5):
    '''
    plots the share of missing value per variable
        
    INPUT:
        share_missing: panda series created with missing_per_variable()
        cutoff: minimum share (0-100) to be included in the plot
        
    OUTPUT:
        nothing (plots the graph on the notebook)
    '''
    
    share_missing[share_missing>cutoff].sort_values().plot.bar(
        figsize=(15,10), 
        color=(0.2, 0.4, 0.6, 0.6)
    )
    plt.title("Ordered barplot of missing values per feature")
    plt.ylabel("Share of missing values (%)")
    plt.show()

# %%
 # check missing per variables:
share_missing = missing_per_variable(data)
# Out:
# count    689.000000
# mean      25.291514
# std       32.596694
# min        0.000000
# 25%        0.000000
# 50%        1.742919
# 75%       55.700799
# 90%       78.576616
# 95%       91.430646
# 99%       99.709513
# max       99.709513
# dtype: float64

# %% [markdown]
# We see that there are still variables with many missing values.

# %% [markdown]
# Let's plot to confirm:

# %%
plot_missing(share_missing)

# %% [markdown]
# Even though the graph is not readable, it confirms that some variables have many missing values.
#
# Let's first take a look a the most problematic variables:

# %%
# problems:
problem = share_missing[share_missing>70]
print(len(problem), " problems")
list(problem.index)
# Out:
# 117  problems
# ['all_land_leasedout_landunit_ha',
#  'cocoa_trees_num',
#  'cocoa_land_dec_how_5ago',
#  'cocoa_intercrop_25yo',
#  'cocoa_tree_spacing_trees',
#  'cocoa_tree_spacing_rows',
#  'cocoa_manurecomp_hhhiredcom_1',
#  'cocoa_manurecomp_hhhiredcom_2',
#  'cocoa_manurecomp_hhhiredcom_3',
#  'cocoa_manurecomp_hhhiredcom_4',
#  'cocoa_manurecomp_gender_1',
#  'cocoa_manurecomp_gender_2',
#  'cocoa_irrigation_source_1',
#  'cocoa_irrigation_source_2',
#  'cocoa_irrigation_source_3',
#  'cocoa_irrigation_source_4',
#  'cocoa_irrigation_source_5',
#  'cocoa_irrigation_source_6',
#  'cocoa_irrigation_source_7',
#  'cocoa_irrigation_method_1',
#  'cocoa_irrigation_method_2',
#  'cocoa_irrigation_method_3',
#  'cocoa_irrigation_method_4',
#  'cocoa_irrigation_method_5',
#  'cocoa_irrigation_method_6',
#  'cocoa_irrigation_method_7',
#  'cocoa_losses_storage_affect',
#  'cocoa_cert_type_clean_1',
#  'cocoa_cert_type_clean_2',
#  'cocoa_cert_type_clean_3',
# ...

# %% [markdown]
# I see that the variables on tree numbers and spacing can also be dropped, since they have too many missing values.

# %%
data.drop([ 
    'cocoa_trees_num',
    'cocoa_land_dec_how_5ago',
    'cocoa_tree_spacing_trees',
    'cocoa_tree_spacing_rows',
    'cocoa_trees_most'
], axis = 1, inplace = True)

# %% [markdown]
# I see from the above that the variables on irrigation source is missing (since no one irrigates cocoa). These can be droped.
#
# Check that indeed (almost) no one irrigates cocoa:

# %%
data['cocoa_irrigation_yn'].value_counts()
# Out:
# no     1373
# yes       4
# Name: cocoa_irrigation_yn, dtype: int64

# %%
data.drop(list(data.filter(regex = 'irrigation')), axis = 1, inplace = True)

# %% [markdown]
# The list also indicated that Minimum Dietary Diversity (MDD) variables is missing for most observations. This is by construction since these questions were asked only of female respondents. As much it is a potential good indicator, it is skipped for the majority of the sample, so I will drop those

# %%
data.drop(list(data.filter(regex='MDD')), axis = 1, inplace = True)
data.drop(list(data.filter(regex='nutrition')), axis = 1, inplace = True)

# %% [markdown]
# The list also shows many missing for land leased out. It is likely the value is only filled for thos who did lease. Let's check

# %%
data.loc[data['all_land_leasedout_yn']=='no', 'all_land_leasedout_landunit_ha'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: all_land_leasedout_landunit_ha, dtype: float64

# %%
data.loc[data['all_land_leasedout_yn']=='yes', 'all_land_leasedout_landunit_ha'].describe()
# Out:
# count    45.000000
# mean      2.338280
# std       2.298098
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.500000
# max      10.000000
# Name: all_land_leasedout_landunit_ha, dtype: float64

# %% [markdown]
# Let's impose `0` if not leased out and `no` if `0` was leased out:

# %%
data.loc[data['all_land_leasedout_yn']=='no', 'all_land_leasedout_landunit_ha']=0

# %%
data.loc[data['all_land_leasedout_landunit_ha']==0, 'all_land_leasedout_yn']='no'

# %% [markdown]
# The list above also showed missing values for times, hh_hi and gender in manure application. This is likely because the application of manure was `no` for most farmers. Let's double check:

# %%
data['cocoa_manurecomp_yn'].value_counts()
# Out:
# no     1305
# yes      72
# Name: cocoa_manurecomp_yn, dtype: int64

# %%
data['cocoa_manurecomp_gender_1'].value_counts()
# Out:
# yes    66
# no      6
# Name: cocoa_manurecomp_gender_1, dtype: int64

# %% [markdown]
# This is indeed the case. This is actually the case for many `yes/no` indicators, where the detailed question are missing in case the first one is `no`. Therefore we will impose `no` to all missing features related to `no` answer from a previous  `yes/no` question

# %%
yes_no_questions = list(data.filter(regex = "_yn"))
yes_no_questions
# Out:
# ['all_land_leasedout_yn',
#  'cocoa_intercrop_yn',
#  'cocoa_trees_rows_yn',
#  'cocoa_landclear_yn',
#  'cocoa_landprep_yn',
#  'cocoa_planting_yn',
#  'cocoa_gfert_yn',
#  'cocoa_lfert_yn',
#  'cocoa_manurecomp_yn',
#  'cocoa_herb_yn',
#  'cocoa_pest_yn',
#  'cocoa_fung_yn',
#  'cocoa_weed_yn',
#  'cocoa_pruning_yn',
#  'cocoa_harvest_yn',
#  'cocoa_podbreak_yn',
#  'cocoa_ferment_yn',
#  'cocoa_transport_yn',
#  'cocoa_dry_yn',
#  'cocoa_losses_disease_yn',
#  'cocoa_losses_pests_yn',
#  'cocoa_losses_storage_yn',
#  'cocoa_records_yn',
#  'cocoa_training_5years_yn',
#  'cocoa_training_lastyear_yn',
#  'cocoa_certification_clean_yn',
#  'cocoa_credit_yn',
#  'loan_lastyear_yn']

# %% [markdown]
# Let's create a supporting function

# %%
def impose_yn_logic(data, data_properties, main_feature, features_to_clean_main_stub = '', yes_no_label = 'lblYES_NO', verbose = 1):
    '''
    Imposes yes/no logic in the data. If a main question is `no` all children should also be `no`
        
    INPUT:
        data: panda DataFrame
        data_properties: StataRead dictionary object created with pd.read_stata(filename, iterator = True)
        main_feature: yes/no parent feature
        features_to_clean_main_stub (optional): main stub to find the children features. If not provided the main stub is 
            derived from the main_feature, removing `_yn` string
        yes_no_label: (stata) label that maps YES/NO questions
        verbose: if greater than 0, prints informative messages
        
    OUTPUT:
        data: modified panda DataFrame
    '''
    
        
    #if no main stub is passed, find the main stub, excluding the "yn"
    if features_to_clean_main_stub == '':
        main_stub = main_feature.replace("_yn","")
    else:
        main_stub = features_to_clean_main_stub
    
    # get a list of all other variable with the same stub
    features_to_clean = list(data.filter(regex = main_stub))
    try:
        features_to_clean.remove(main_feature)
    except:
        ;
    
    if verbose >=1:
        print('')
        print("Based on {}, clean:".format(main_feature))
        print(features_to_clean)
    
    
    # for each feature in the list, if the feature is a yes/no question, impose 'no' if main is 'no'
    for this_feature, this_label in zip(data_properties.varlist, data_properties.lbllist):
        if (this_feature in features_to_clean) & (this_label == yes_no_label):
            data.loc[data[main_feature]=='no', this_feature] = 'no'
            
    return data

# %%
for main_question in yes_no_questions:
    
    # for each feature in the list, if the feature is a yes/no question, impose 'no' if main is 'no'
    data = impose_yn_logic(data, data_properties, main_question)
# Out:
# Based on all_land_leasedout_yn, clean:
# ['all_land_leasedout_landunit_ha']
#
# Based on cocoa_intercrop_yn, clean:
# ...

# %% [markdown]
# I see that `cocoa_credit_whom` is an specification from `cocoa_credit_yn`, but it is not a yes/no question. Since it only provides some additional infomation for those taking inputs on credit, I will drop it

# %%
data.drop(list(data.filter(regex = 'cocoa_credit_whom')), axis = 1, inplace = True)

# %% [markdown]
# I also see from above that features `cocoa_trees_rows_yn`, `cocoa_training_5years_yn`, `cocoa_training_lastyear_yn`, `cocoa_certification_clean_yn`, `loan_lastyear_yn` didn't trigger any additional adjustments. Except for `cocoa_trees_rows_yn` and `cocoa_training_lastyear_yn` (no dependents) these are special cases, where feature naming convention is different.

# %%
data = impose_yn_logic(data, data_properties, 'loan_lastyear_yn',  'loan')
data = impose_yn_logic(data, data_properties, 'cocoa_training_5years_yn',  'cocoa_training_')
data = impose_yn_logic(data, data_properties, 'cocoa_certification_clean_yn',  'cocoa_cert_type_clean_')
# Out:
# Based on loan_lastyear_yn, clean:
# ['loan_source_1', 'loan_source_2', 'loan_source_3', 'loan_source_4', 'loan_source_5', 'loan_source_6', 'loan_source_7', 'loan_source_8', 'loan_source_9', 'loan_source_10', 'loan_source_11', 'loan_source_12', 'loan_source_13', 'loan_source_999', 'loan_amount_usd', 'loan_repayment_success', 'loan_repayment_c', 'loan_use_1', 'loan_use_2', 'loan_use_3', 'loan_use_4', 'loan_use_5', 'loan_use_6', 'loan_use_7', 'loan_use_8', 'loan_use_9', 'loan_use_10', 'loan_use_11', 'loan_use_12', 'loan_use_13', 'loan_use_14', 'loan_use_15', 'loan_use_16', 'loan_use_17', 'loan_use_19', 'loan_use_20', 'loan_use_18', 'loan_use_999', 'noloan_whynot_1', 'noloan_whynot_2', 'noloan_whynot_3', 'noloan_whynot_4', 'noloan_whynot_5', 'noloan_whynot_6', 'noloan_whynot_7', 'noloan_whynot_8']
#
# Based on cocoa_training_5years_yn, clean:
# ...

# %% [markdown]
# I can see from above that there are features related to `noloan`. Since this is undefined for those who did take a loan, I will drop it to keep only features which are meaningfull for the whole sample. Similar argument applies to loan collateral and loan repayment success

# %%
data.drop(list(data.filter(regex = 'noloan')), axis = 1, inplace = True)
data.drop(list(data.filter(regex = 'loan_repayment')), axis = 1, inplace = True)

# %% [markdown]
# I can also see that `loan_amount_` is there, and this should be 0 if no loan was taken

# %%
data.loc[data['loan_lastyear_yn']=='no', 'loan_amount_usd']=0
data.loc[data['loan_amount_usd']==0, 'loan_lastyear_yn']='no'

# %% [markdown]
# Similarly I see that `cocoa_training_days_cat` should be 0 if no training was taken:

# %%
data.loc[data['cocoa_training_5years_yn']=='no', 'cocoa_training_days_cat']='none'

# %% [markdown]
# I had also seen that the features on `cocoa_prodgroup_services_` are missing. These are specification of services provided by producer groups

# %%
data = impose_yn_logic(data, data_properties, 'cocoa_prodgroup_hhmem',  'cocoa_prodgroup_services_')
# Out:
# Based on cocoa_prodgroup_hhmem, clean:
# ['cocoa_prodgroup_services_1', 'cocoa_prodgroup_services_2', 'cocoa_prodgroup_services_3', 'cocoa_prodgroup_services_4', 'cocoa_prodgroup_services_5', 'cocoa_prodgroup_services_6', 'cocoa_prodgroup_services_7', 'cocoa_prodgroup_services_8', 'cocoa_prodgroup_services_9', 'cocoa_prodgroup_services_10', 'cocoa_prodgroup_services_999']

# %% [markdown]
# Let's check what is over:

# %%
 # check missing per variables:
share_missing = missing_per_variable(data)
# Out:
# count    630.000000
# mean       1.556178
# std        8.413180
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# 90%        1.161946
# 95%        3.848947
# 99%       55.908497
# max       86.347131
# dtype: float64

# %%
plot_missing(share_missing)

# %% [markdown]
# We see that `_affect` variables are missing. They measure how affected farmer were by different types of losses. Since this is only relevant when they occur, let's drop them.

# %%
data.drop(list(data.filter(regex = '_affect')), axis = 1, inplace = True)

# %% [markdown]
# We also see that a few of the `hh_` variables are missing. These are variables that were only collected in Côte d'Ivoire

# %%
data.drop(['hh_fan', 'hh_tractor', 'hh_gaselectric_stove', 'hh_cable_subscription'],
         axis = 1, inplace = True)

# %% [markdown]
# Similarly to `PPI_190` and `PPI_310`

# %%
data.drop(['PPI_190dollar_day', 'PPI_310dollar_day'], axis = 1, inplace = True)

# %% [markdown]
# Actually I will drop all `DHS` and `PPI` indices variables, since they are asset-based indices, and I want to predict achieving the benchmark regardless of those

# %%
data.drop(list(data.filter(regex = 'dhs')), axis = 1, inplace = True)
data.drop(list(data.filter(regex = 'PPI')), axis = 1, inplace = True)

# %% [markdown]
# Some detailed features on `mosquito nets` are also dependent on having said `yes` to mosquito net. Let's impose the logic

# %%
data = impose_yn_logic(data, data_properties, 'hh_mosquito_net')
# Out:
# Based on hh_mosquito_net, clean:
# ['hh_mosquito_net_num', 'hh_mosquito_net_lastnight']

# %%
data.loc[data['hh_mosquito_net']=='no', 'hh_mosquito_net_num']=0

# %% [markdown]
# The feature on `cocoa_intercrop_25yo` seems to have too many missing, even after the logic imposing. I will drop it the whole set

# %%
data.drop(['cocoa_intercrop_5yo', 'cocoa_intercrop_5_25yo', 'cocoa_intercrop_25yo'], axis = 1, inplace = True)

# %% [markdown]
# The feature `cocoa_land_inc_how_5ago` applies only to farmers that increased land. So I will drop to keep the features generic

# %%
data.drop(['cocoa_land_inc_how_5ago'], axis = 1, inplace = True)

# %% [markdown]
# Let's impose that land was not leased out if missing, since this was the most common answer:

# %%
data.loc[data['all_land_leasedout_yn'].isnull(), 'all_land_leasedout_yn']='no'
data.loc[data['all_land_leasedout_yn']=='no', 'all_land_leasedout_landunit_ha']=0

# %% [markdown]
# The indicator of all children at school only applies to farmers with children in school age. To make it complete, I will set all children at school to `yes` if no childrens present, since this is the more neutral answer in this context

# %%
data.loc[data['male_children_5_14']==0, 'male_children_5_14_school']='yes'
data.loc[data['female_children_5_14']==0, 'female_children_5_14_school']='yes'

# %% [markdown]
# I'll set none for `crops_important2` where missing:

# %%
data.loc[data['crops_important2'].isnull(), 'crops_important2']='none/ not applicable'

# %% [markdown]
# Let's do a final check:

# %%
 # check missing per variables:
share_missing = missing_per_variable(data)
# Out:
# count    609.000000
# mean       0.267233
# std        1.019338
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# 90%        0.871460
# 95%        2.251271
# 99%        3.921569
# max       15.177923
# dtype: float64

# %%
plot_missing(share_missing)

# %% [markdown]
# # 4 Final Details

# %% [markdown]
# Before finishing, I'll replace the binary categories by their numeric values (0 or 1)

# %%
def convert_tocodes(data, data_properties, label_name):
    '''
    Convert categories to numeric values, according to the stata dictionaty
        
    INPUT:
        data: panda DataFrame
        data_properties: StataRead dictionary object created with pd.read_stata(filename, iterator = True)
        label_name: (stata) label that maps categories in that question
        
    OUTPUT:
        data: modified panda DataFrame
    '''
    
    # make a dataframe
    data_and_label = pd.DataFrame({
        "variable label": data_properties.varlist,
        "value label": data_properties.lbllist})
    
    # filter on the selected label
    data_and_label = data_and_label[data_and_label['value label']==label_name]

    # convert all features that use that label
    for this_column in list(data.columns):

        if this_column in list(data_and_label['variable label']):
            data[this_column] = data[this_column].cat.codes
            data.loc[data[this_column] == -1, this_column] = np.nan
            
    return data

# %% [markdown]
# Let's see how they look like before applying the function

# %%
data['head_gender'].value_counts()
# Out:
# male      1227
# female     150
# Name: head_gender, dtype: int64

# %%
data['cocoa_gfert_yn'].value_counts()
# Out:
# no     926
# yes    451
# Name: cocoa_gfert_yn, dtype: int64

# %%
data = convert_tocodes(data, data_properties, "lblYES_NO")
data = convert_tocodes(data, data_properties, "lblMALE_FEMALE")

# %% [markdown]
# Let's see how they look like AFTER applying the function

# %%
data['head_gender'].value_counts()
# Out:
# 0.0    1227
# 1.0     150
# Name: head_gender, dtype: int64

# %%
data['cocoa_gfert_yn'].value_counts()
# Out:
# 0.0    926
# 1.0    451
# Name: cocoa_gfert_yn, dtype: int64

# %% [markdown]
# Let's rename the columns to a more meaningful values

# %%
list(data.columns)
# Out:
# ['country',
#  'region',
#  'hhmem_number',
#  'male_adults_over_65',
#  'female_adults_over_65',
#  'male_adults_15_65',
#  'female_adults_15_65',
#  'male_children_5_14',
#  'female_children_5_14',
#  'male_children_0_4',
#  'female_children_0_4',
#  'dep_ratio',
#  'head_age',
#  'head_age_cat',
#  'head_gender',
#  'head_education',
#  'male_children_5_14_school',
#  'female_children_5_14_school',
#  'incsource_biggest1',
#  'incsource_biggest2',
#  'hh_income_perc_cocoa',
#  'hh_income_perc_othercrops',
#  'hh_income_perc_livestock',
#  'hh_income_perc_fish',
#  'hh_income_perc_bushproducts',
#  'hh_income_perc_farmlabour',
#  'hh_income_perc_nonaglabour',
#  'hh_income_perc_smallbusiness',
#  'hh_income_perc_comp',
#  'hh_income_perc_govt',
#  'hh_income_perc_landsalelease',
#  'hh_income_perc_remittances',
#  'hh_income_perc_other',
#  'crops_all_produced_1',
#  'crops_all_produced_2',
#  'crops_all_produced_3',
#  'crops_all_produced_4',
#  'crops_all_produced_5',
# ...

# %% [markdown]
# First some manual cases:

# %%
data.rename(columns = {"head_gender" : "Female head"}, inplace = True)

# %%
data.rename(columns = {
     "cocoa_training_source_1": "Training from farmer organisation",
    "cocoa_training_source_2": "Training from government extension",
    "cocoa_training_source_3": "Training from trader",
    "cocoa_training_source_4": "Training from company, lbc",
    "cocoa_training_source_5": "Training from ngo",
    "cocoa_training_source_6": "Training from other"
}, inplace = True)

# %% [markdown]
# Now remaing cases using the stata dictionary

# %%
data.rename(columns =  data_properties.variable_labels(), inplace = True )

# %%
list(data.columns)
# Out:
# ['Country',
#  'Region',
#  'Number of household members living in the compound',
#  'Number of males over 65 years old',
#  'Number of females over 65 years old',
#  'Number of males 15-65',
#  'Number of females between 15 and 65 years old',
#  'Number of boys between 15 and 65 years old',
#  'Number of girls  between 5 and 14 years old',
#  'Number of boys younger than 4 years old',
#  'Number of girls younger than 4 years old',
#  'Dependency ratio',
#  'Head: age',
#  'Head: age group',
#  'Female head',
#  'Head: education level',
#  'All household boys ages 5 to 14 currently attending school',
#  'All household girls ages 5 to 14 currently attending school',
#  "Household's biggest source of income in last year",
#  "Household's second biggest source of income in last year",
#  'Estimated income percentage from sale of cocoa',
#  'Estimated income percentage from sale of other crops',
#  'Estimated income percentage from sale of livestock or livestock products',
# ...

# %% [markdown]
# Let's do a final check per country:

# %%
data['Country'].value_counts()
# Out:
# Ghana    970
# CdI      407
# Name: Country, dtype: int64

# %% [markdown]
# Final check overall:

# %%
data.describe()
# Out:
#        Number of household members living in the compound  \
# count                                        1365.000000
# mean                                            6.190476
# std                                             3.002501
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             6.000000
# 75%                                             8.000000
# max                                            21.000000
#
#        Number of males over 65 years old  Number of females over 65 years old  \
# count                        1365.000000                          1365.000000
# mean                            0.133333                             0.109158
# std                             0.369010                             0.351719
# min                             0.000000                             0.000000
# ...

# %% [markdown]
# ## Export

# %%
data.to_pickle('../data/data_ready_for_ML.pkl')
